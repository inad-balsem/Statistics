# %% [markdown]
# ### Pretest Usecased
# **Telkomsel Data Science Academy**
# <br> **Date** : 16 October 2019
# <br> created by **iNad**
#
# ***

# %% [markdown]
# ### 1. Explore the dataset & get the preview from the data statistic

# %%
import pandas as pd
import numpy as np
import statistics as st

# %%
df = pd.read_csv('churn.csv')
df.head(10)
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
# 5      1             118        510          3355                   1
# 6     19             121        510          1516                   0
# 7     24             147        415           116                   1
# 8     18             117        408           425                   0
# 9     49             141        415           163                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# ...

# %%
df.describe()
# Out:
#             state  account_length    area_code  phone_number  \
# count  5000.00000      5000.00000  5000.000000   5000.000000
# mean     25.99840       100.25860   436.911400   2499.500000
# std      14.80348        39.69456    42.209182   1443.520003
# min       0.00000         1.00000   408.000000      0.000000
# 25%      13.00000        73.00000   408.000000   1249.750000
# 50%      26.00000       100.00000   415.000000   2499.500000
# 75%      39.00000       127.00000   415.000000   3749.250000
# max      50.00000       243.00000   510.000000   4999.000000
#
#        international_plan  voice_mail_plan  number_vmail_messages  \
# count         5000.000000      5000.000000            5000.000000
# mean             0.094600         0.264600               7.755200
# std              0.292691         0.441164              13.546393
# min              0.000000         0.000000               0.000000
# 25%              0.000000         0.000000               0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
# state                            5000 non-null int64
# account_length                   5000 non-null int64
# area_code                        5000 non-null int64
# phone_number                     5000 non-null int64
# international_plan               5000 non-null int64
# voice_mail_plan                  5000 non-null int64
# number_vmail_messages            5000 non-null int64
# total_day_minutes                5000 non-null float64
# total_day_calls                  5000 non-null int64
# total_day_charge                 5000 non-null float64
# total_eve_minutes                5000 non-null float64
# total_eve_calls                  5000 non-null int64
# total_eve_charge                 5000 non-null float64
# total_night_minutes              5000 non-null float64
# total_night_calls                5000 non-null int64
# ...

# %% [markdown]
# Conclusion:
# <br> 1. there are 5000 row data and 21 coloumns
# <br> 2. all of the colomn have the numerical type data

# %% [markdown]
# ### 2. What is the absolute correlation value of all numeric variables toward 'class'?

# %%
abs(df.corr()['class']).sort_values(ascending = False).head(10)
# Out:
# class                            1.000000
# international_plan               0.259123
# number_customer_service_calls    0.212564
# total_day_minutes                0.207705
# total_day_charge                 0.207700
# voice_mail_plan                  0.110698
# number_vmail_messages            0.097633
# total_eve_minutes                0.089288
# total_eve_charge                 0.089282
# total_intl_minutes               0.063285
# Name: class, dtype: float64

# %%
df.columns
# Out:
# Index(['state', 'account_length', 'area_code', 'phone_number',
#        'international_plan', 'voice_mail_plan', 'number_vmail_messages',
#        'total_day_minutes', 'total_day_calls', 'total_day_charge',
#        'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
#        'total_night_minutes', 'total_night_calls', 'total_night_charge',
#        'total_intl_minutes', 'total_intl_calls', 'total_intl_charge',
#        'number_customer_service_calls', 'class'],
#       dtype='object')

# %% [markdown]
# Conclusion
# <br> 1. Assume that 1 values on class mean the customer churn
# <br> 2. The most correlation values with churn is international plan column with 0.259123 value

# %% [markdown]
# ### 3. Correlation between customer service call and profile total call

# %%
profile_complain = ["high" if x>2 else "low" for x in df['number_customer_service_calls']]
df['profile_complain'] = profile_complain
df['profile_complain'].head(10)
# Out:
# 0     low
# 1     low
# 2     low
# 3     low
# 4    high
# 5     low
# 6    high
# 7     low
# 8     low
# 9     low
# Name: profile_complain, dtype: object

# %%
df_high_comp = df[df['profile_complain']=="high"]
df_low_comp = df[df['profile_complain']=="low"]
column_select = ['total_day_calls','total_eve_calls','total_night_calls']

# %%
df_high_comp[column_select].mean()
# Out:
# total_day_calls      100.277256
# total_eve_calls      100.546053
# total_night_calls     99.388158
# dtype: float64

# %%
df_low_comp[column_select].mean()
# Out:
# total_day_calls       99.962398
# total_eve_calls      100.095020
# total_night_calls    100.062754
# dtype: float64

# %% [markdown]
# Conclusion:
# <br> there are almost no relation between customer service call and call activity

# %% [markdown]
# ### 4. Profile country with the highest churn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df['state'].unique()
# Out:
# array([16, 35, 31, 36,  1, 19, 24, 18, 49, 15, 39, 12, 26, 34, 13, 46, 45,
#        43,  9,  5,  3, 40, 29, 50, 11, 14, 30, 10,  0, 20,  2, 48, 37, 22,
#         8, 44,  4, 23, 41, 27, 47, 32, 33,  7, 17, 21, 25, 42, 38,  6, 28],
#       dtype=int64)

# %%
df['class'].unique()
df_churn = df[df['class']==1]

# %%
plt.figure(figsize=(10,10))
g = sns.countplot(x="state", data = df_churn, palette = 'Set1')
g.set_xticklabels(g.get_xticklabels(), rotation = 90, ha ="right")
g
plt.title('State VS Churn Profile', size = 20)
# Out:
# Text(0.5, 1.0, 'State VS Churn Profile')

# %% [markdown]
# Conclusion
# <br> the highest churn is from state with code 31

# %% [markdown]
# ### 5. Profile churn

# %%
df_churn.describe()
# Out:
#             state  account_length   area_code  phone_number  \
# count  707.000000      707.000000  707.000000    707.000000
# mean    26.251768      102.332390  437.971711   2543.499293
# std     14.228766       39.396993   42.848131   1425.252780
# min      0.000000        1.000000  408.000000      5.000000
# 25%     15.000000       76.000000  411.500000   1310.500000
# 50%     26.000000      102.000000  415.000000   2576.000000
# 75%     38.000000      126.500000  510.000000   3770.000000
# max     50.000000      225.000000  510.000000   4985.000000
#
#        international_plan  voice_mail_plan  number_vmail_messages  \
# count          707.000000       707.000000             707.000000
# mean             0.281471         0.144272               4.496464
# std              0.450035         0.351614              11.297719
# min              0.000000         0.000000               0.000000
# 25%              0.000000         0.000000               0.000000
# ...

# %%
#df_churn_select=df_churn['total_day_minutes','total_day_calls','total_eve_minutes','total_eve_calls','total_night_minutes','total_night_calls']
#df_churn_select.hist()
df_churn.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023D26394D48>,
# ...
#       dtype=object)

# %% [markdown]
# conclusion
# <br> 1. there are 707 subscriber churn
